# %%
import sys; sys.path.append('..')

# %%
from data_utils import CompanyDataHandler

# %%
CompanyDataHandler()
# Out:
# Loading company data from directory: /Users/dylan/Coding/DS205/tpi-apis/data/TPI sector data - All sectors - 08032025
# Found latest company assessments file: /Users/dylan/Coding/DS205/tpi-apis/data/TPI sector data - All sectors - 08032025/Company_Latest_Assessments_5.0.csv
# Loaded 2060 company records

# %%
from data_utils import CPHandler
CPHandler().get_df().columns
# Out:
#           company name                 geography geography code  \
# 0                  ACC                     India            IND
# 1                  ACC                     India            IND
# 2                  ACC                     India            IND
# 3                  ACC                     India            IND
# 4                ADBRI                 Australia            AUS
# ...                ...                       ...            ...
# 2510  WEC Energy Group  United States of America            USA
# 2511       XCEL Energy  United States of America            USA
# 2512       XCEL Energy  United States of America            USA
# 2513       XCEL Energy  United States of America            USA
# 2514       XCEL Energy  United States of America            USA
#
#                      sector ca100 focus company large/medium classification  \
# 0                    Cement                  No                      medium
# ...

# %%
CPHandler().get_df().columns
# Out:
# Index(['company name', 'geography', 'geography code', 'sector',
#        'ca100 focus company', 'large/medium classification', 'isins', 'sedol',
#        'publication date', 'assessment date',
#        'carbon performance alignment 2025',
#        'carbon performance alignment 2027',
#        'carbon performance alignment 2028',
#        'carbon performance alignment 2035',
#        'carbon performance alignment 2050', 'benchmark id',
#        'years with targets', 'history to projection cutoff year', 'cp unit',
#        'assumptions', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028',
#        '2029', '2030', '2031', '2032', '2033', '2034', '2035', '2036', '2037',
#        '2038', '2039', '2040', '2041', '2042', '2043', '2044', '2045', '2046',
#        '2047', '2048', '2049', '2050', 'assessment_cycle', 'region',
#        'carbon performance regional alignment 2025',
# ...

# %%
print(CPHandler().get_df().head(1))
# Out:
#   company name geography geography code  sector ca100 focus company  \
# 0          ACC     India            IND  Cement                  No
#
#   large/medium classification         isins    sedol publication date  \
# 0                      medium  INE012A01025  6155915       01/08/2024
#
#   assessment date  ...  2049 2050  assessment_cycle region  \
# 0      16/07/2024  ...  0.02  0.0                 1    NaN
#
#   carbon performance regional alignment 2025  \
# 0                                        NaN
#
#   carbon performance regional alignment 2027  \
# 0                                        NaN
#
#   carbon performance regional alignment 2028  \
# 0                                        NaN
#
#    carbon performance regional alignment 2035  \
# 0                                         NaN
#
#   carbon performance regional alignment 2050 regional benchmark id
# 0                                        NaN                   NaN
#
# [1 rows x 66 columns]
