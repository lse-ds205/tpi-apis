# %%
import sys; sys.path.append('..')
from data_utils import DataHandler

# %%
data_handler = DataHandler()

# %%
data_handler.mq.mq_files

# %%
data_handler.mq.load_mq_data()
# Out:
#                                         company name  \
# 0                                    Yankuang Energy
# 1                                              ADBRI
# 2                                    APA Corporation
# 3                                           Acerinox
# 4                                       Adaro Energy
# ...                                              ...
# 8313                              Zijin Mining Group
# 8314                          Zimmer Biomet Holdings
# 8315                                          Zoetis
# 8316  Zoomlion Heavy Industry Science and Technology
# 8317                          Zurich Insurance Group
#
#                      geography geography code           sector ca100 company?  \
# 0                        China            CHN      Coal Mining             No
# 1                    Australia            AUS           Cement            Yes
# 2     United States of America            USA        Oil & Gas             No
# ...

# %%
data_handler.mq.get_mq_files_length()
# Out:
# 5

# %%
data_handler.mq.mq_files
# Out:
# [PosixPath('/Users/dylan/Coding/DS205/tpi-apis/data/TPI sector data - All sectors - 08032025/MQ_Assessments_Methodology_1_08032025.csv'),
#  PosixPath('/Users/dylan/Coding/DS205/tpi-apis/data/TPI sector data - All sectors - 08032025/MQ_Assessments_Methodology_2_08032025.csv'),
#  PosixPath('/Users/dylan/Coding/DS205/tpi-apis/data/TPI sector data - All sectors - 08032025/MQ_Assessments_Methodology_3_08032025.csv'),
#  PosixPath('/Users/dylan/Coding/DS205/tpi-apis/data/TPI sector data - All sectors - 08032025/MQ_Assessments_Methodology_4_08032025.csv'),
#  PosixPath('/Users/dylan/Coding/DS205/tpi-apis/data/TPI sector data - All sectors - 08032025/MQ_Assessments_Methodology_5_08032025.csv')]
