# %%
import pandas as pd

# %%
file_path = './data/TPI ASCOR data - 13012025/ASCOR_assessments_results.xlsx'

df = pd.read_excel(file_path)

# %%
df['Publication date']=pd.to_datetime(df['Publication date'], format='%d/%m/%Y')
df['Assessment date']=pd.to_datetime(df['Assessment date'], format='%d/%m/%Y')

selected_country = 'United Kingdom'
selected_year = 2023

# %%
mask = (
    (df['Country']==selected_country)&
    (df['Assessment date'].dt.year==selected_year)
)

df[mask].iloc[0].to_dict()
# Out:
# {'Id': 86,
#  'Assessment date': Timestamp('2023-10-31 00:00:00'),
#  'Publication date': Timestamp('2023-12-01 00:00:00'),
#  'Country Id': 22,
#  'Country': 'United Kingdom',
#  'area EP.1': 'Partial',
#  'indicator EP.1.a': 'Yes',
#  'indicator EP.1.b': 'No',
#  'indicator EP.1.c': 'No',
#  'area EP.2': 'Partial',
#  'indicator EP.2.a': 'Yes',
#  'metric EP.2.a.i': "'-42%",
#  'indicator EP.2.b': 'No',
#  'metric EP.2.b.i': 'No or unsuitable disclosure',
#  'indicator EP.2.c': 'No',
#  'metric EP.2.c.i': '37%',
#  'indicator EP.2.d': 'No',
#  'metric EP.2.d.i': '162%',
#  'area EP.3': 'Partial',
#  'indicator EP.3.a': 'Yes',
#  'metric EP.3.a.i': '2050',
#  'indicator EP.3.b': 'Yes',
#  'indicator EP.3.c': 'No',
#  'area CP.1': 'Yes',
#  'indicator CP.1.a': 'Yes',
#  'indicator CP.1.b': 'Yes',
#  'area CP.2': 'Partial',
#  'indicator CP.2.a': 'Yes',
#  'indicator CP.2.b': 'No',
#  'metric CP.2.b.i': '28%',
#  'indicator CP.2.c': 'Yes',
#  'metric CP.2.c.i': 'US$ 92.96/tCO₂e',
#  'area CP.3': 'No',
#  'indicator CP.3.a': 'No',
#  'metric CP.3.a.i': 'No or unsuitable disclosure',
#  'indicator CP.3.b': 'No',
#  'metric CP.3.b.i': '0.49%',
#  'indicator CP.3.c': 'No',
#  'metric CP.3.c.i': '0.00%',
#  'indicator CP.3.d': 'No',
#  'metric CP.3.d.i': '0.42%',
#  'metric CP.3.d.ii': '0.17%',
#  'area CP.4': 'Partial',
#  'indicator CP.4.a': 'Yes',
#  'indicator CP.4.b': 'No',
#  'metric CP.4.b.i': '2.23 MJ/US$ PPP-adjusted GDP',
#  'indicator CP.4.c': 'Yes',
#  'metric CP.4.d.i': '57%',
#  'indicator CP.4.d': 'Yes',
#  'indicator CP.4.e': 'No',
#  'metric CP.4.e.i': '28%',
#  'area CP.5': 'Yes',
#  'indicator CP.5.a': 'Yes',
#  'indicator CP.5.b': 'Yes',
#  'indicator CP.5.c': 'Yes',
#  'indicator CP.5.d': 'Yes',
#  'indicator CP.5.e': 'Exempt',
#  'area CP.6': 'Partial',
#  'indicator CP.6.a': 'Yes',
#  'metric CP.6.a.i': '0.93',
#  'indicator CP.6.b': 'No',
#  'indicator CP.6.c': 'Yes',
#  'indicator CP.6.d': 'No',
#  'area CF.1': 'Partial',
#  'indicator CF.1.a': 'No',
#  'metric CF.1.a.i': '0.01%',
#  'indicator CF.1.b': 'Yes',
#  'metric CF.1.b.i': '0.08%',
#  'area CF.2': 'Exempt',
#  'indicator CF.2.a': 'Exempt',
#  'indicator CF.2.b': 'Exempt',
#  'area CF.3': 'Yes',
#  'indicator CF.3.a': 'Yes',
#  'indicator CF.3.b': 'Yes',
#  'area CF.4': 'Not applicable',
#  'metric CF.4.i': '6.65 MW/US$ billion GDP',
#  'metric CF.4.ii': '41.82 MW/US$ billion GDP',
#  'metric CF.4.iii': '0.1 MW/US$ billion GDP',
#  'metric CF.4.iv': '1.85 MW/US$ billion GDP',
#  'source indicator EP.1.a': nan,
#  'source metric EP.1.a.i': nan,
#  'source metric EP.1.a.ii': nan,
#  'source indicator EP.1.b': 'https://1p5ndc-pathways.climateanalytics.org/',
#  'source indicator EP.1.c': 'https://transitionpathwayinitiative.org/publications/uploads/2023-ascor-framework-methodology-note',
#  'source indicator EP.2.a': 'https://unfccc.int/sites/default/files/NDC/2022-06/UK%20Nationally%20Determined%20Contribution.pdf',
#  'source metric EP.2.a.i': 'https://unfccc.int/sites/default/files/NDC/2022-06/UK%20Nationally%20Determined%20Contribution.pdf',
#  'source indicator EP.2.b': 'https://unfccc.int/sites/default/files/NDC/2022-06/UK%20Nationally%20Determined%20Contribution.pdf',
#  'source metric EP.2.b.i': nan,
#  'source indicator EP.2.c': 'https://1p5ndc-pathways.climateanalytics.org/',
#  'source metric EP.2.c.i': 'https://1p5ndc-pathways.climateanalytics.org/',
#  'source indicator EP.2.d': 'https://transitionpathwayinitiative.org/publications/uploads/2023-ascor-framework-methodology-note',
#  'source metric EP.2.d.i': 'https://transitionpathwayinitiative.org/publications/uploads/2023-ascor-framework-methodology-note',
#  'source indicator EP.3.a': 'https://www.legislation.gov.uk/ukdsi/2019/9780111187654',
#  'source metric EP.3.a.i': 'https://www.legislation.gov.uk/ukdsi/2019/9780111187654',
#  'source indicator EP.3.b': 'https://www.legislation.gov.uk/ukdsi/2019/9780111187654',
#  'source indicator EP.3.c': 'https://www.legislation.gov.uk/ukdsi/2019/9780111187654',
#  'source indicator CP.1.a': 'https://www.legislation.gov.uk/ukpga/2008/27/contents',
#  'source indicator CP.1.b': 'https://www.legislation.gov.uk/ukpga/2008/27/contents',
#  'source indicator CP.2.a': 'https://www.legislation.gov.uk/uksi/2020/1265/made',
#  'source indicator CP.2.b': 'https://stats.oecd.org/Index.aspx?DataSetCode=ECR',
#  'source metric CP.2.b.i': 'https://stats.oecd.org/Index.aspx?DataSetCode=ECR',
#  'source indicator CP.2.c': 'https://www.carbonpricingleadership.org/leadershipreports',
#  'source metric CP.2.c.i': 'https://icapcarbonaction.com/en/ets',
#  'source indicator CP.3.a': nan,
#  'source metric CP.3.a.i': nan,
#  'source indicator CP.3.b': nan,
#  'source metric CP.3.b.i': 'https://www.imf.org/en/Topics/climate-change/energy-subsidies',
#  'source indicator CP.3.c': nan,
#  'source metric CP.3.c.i': 'https://data.worldbank.org/indicator/NY.GDP.COAL.RT.ZS',
#  'source indicator CP.3.d': nan,
#  'source metric CP.3.d.i': 'https://data.worldbank.org/indicator/NY.GDP.PETR.RT.ZS',
#  'source metric CP.3.d.ii': 'https://data.worldbank.org/indicator/NY.GDP.NGAS.RT.ZS',
#  'source indicator CP.4.a': 'https://unfccc.int/sites/default/files/resource/UK%20Net%20Zero%20Strategy%20-%20Build%20Back%20Greener.pdf',
#  'source indicator CP.4.b': nan,
#  'source metric CP.4.b.i': 'https://data.worldbank.org/indicator/EG.EGY.PRIM.PP.KD',
#  'source indicator CP.4.c': 'https://www.legislation.gov.uk/uksi/2022/31/made',
#  'source metric CP.4.d.i': 'https://www.iea.org/data-and-statistics/data-tools/energy-statistics-data-browser?country=WORLD&fuel=Energy%20supply&indicator=ElecGenByFuel',
#  'source indicator CP.4.d': 'https://cdn.climatepolicyradar.org/navigator/GBR/2021/net-zero-strategy-build-back-greener_0fdb5eb8c251d8c2a37a5a1cb4c57f3f.pdf',
#  'source indicator CP.4.e': 'https://data.worldbank.org/indicator/ER.LND.PTLD.ZS',
#  'source metric CP.4.e.i': 'https://www.ibat-alliance.org/country_profiles?locale=en',
#  'source indicator CP.5.a': 'https://www.gov.uk/government/publications/third-national-adaptation-programme-nap3',
#  'source indicator CP.5.b': 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/1047003/climate-change-risk-assessment-2022.pdf',
#  'source indicator CP.5.c': 'https://www.theccc.org.uk/publication/progress-in-adapting-to-climate-change-2023-report-to-parliament/#:~:text=Adaptation%20This%20report%20provides%20the%20Committee%E2%80%99s%20biennial%20report,to%20help%20prepare%20the%20country%20for%20climate%20change.',
#  'source indicator CP.5.d': 'https://www.undrr.org/media/84088/download?startDownload=true',
#  'source indicator CP.5.e': nan,
#  'source indicator CP.6.a': 'https://indicators.ohchr.org/',
#  'source metric CP.6.a.i': 'https://data.worldbank.org/indicator/VA.PER.RNK',
#  'source indicator CP.6.b': nan,
#  'source indicator CP.6.c': 'https://assets.publishing.service.gov.uk/media/6194dfa4d3bf7f0555071b1b/net-zero-strategy-beis.pdf',
#  'source indicator CP.6.d': nan,
#  'source indicator CF.1.a': 'https://unfccc.int/BR5',
#  'source metric CF.1.a.i': 'https://unfccc.int/BR5',
#  'source indicator CF.1.b': 'https://webarchive.nationalarchives.gov.uk/ukgwa/20230401054904/https:/ukcop26.org/wp-content/uploads/2021/11/Table-of-climate-finance-commitments-November-2021.pdf',
#  'source metric CF.1.b.i': 'https://webarchive.nationalarchives.gov.uk/ukgwa/20230401054904/https:/ukcop26.org/wp-content/uploads/2021/11/Table-of-climate-finance-commitments-November-2021.pdf',
#  'source indicator CF.2.a': nan,
#  'source indicator CF.2.b': nan,
#  'source indicator CF.3.a': 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/1043689/Budget_AB2021_Web_Accessible.pdf',
#  'source indicator CF.3.b': 'https://www.gov.uk/government/publications/environmental-impacts-of-spending-review-2021/environmental-impacts-analysis-to-accompany-autumn-budget-and-spending-review-2021',
#  'source metric CF.4.i': 'https://globalenergymonitor.org/projects/global-solar-power-tracker/',
#  'source metric CF.4.ii': 'https://globalenergymonitor.org/projects/global-wind-power-tracker/',
#  'source metric CF.4.iii': 'https://globalenergymonitor.org/projects/global-geothermal-power-tracker/',
#  'source metric CF.4.iv': 'https://globalenergymonitor.org/projects/global-hydropower-tracker/',
#  'year metric EP.1.a.i': nan,
#  'year metric EP.1.a.ii': nan,
#  'year metric EP.2.a.i': 2022,
#  'year metric EP.2.b.i': nan,
#  'year metric EP.2.c.i': 2022.0,
#  'year metric EP.2.d.i': 2023.0,
#  'year metric EP.3.a.i': 2019.0,
#  'year metric CP.2.b.i': 2021.0,
#  'year metric CP.2.c.i': 2022.0,
#  'year metric CP.3.a.i': nan,
#  'year metric CP.3.b.i': 2022.0,
#  'year metric CP.3.c.i': 2021.0,
#  'year metric CP.3.d.i': 2021.0,
#  'year metric CP.3.d.ii': 2021.0,
#  'year metric CP.4.b.i': 2021.0,
#  'year metric CP.4.d.i': 2021.0,
#  'year metric CP.4.e.i': 2022.0,
#  'year metric CP.6.a.i': 2021,
#  'year metric CF.1.a.i': 2020.0,
#  'year metric CF.1.b.i': 2021.0,
#  'year metric CF.4.i': 2023,
#  'year metric CF.4.ii': 2023,
#  'year metric CF.4.iii': 2023,
#  'year metric CF.4.iv': 2023,
#  'Notes': 'Assessment results are based on in-depth policy research drawing on publicly-available government documents or third-party data providers. The principal source for each assessment result is provided. Some indicators and metrics are based on calculations undertaken by the TPI Centre. See the ASCOR methodology note for further details.'}

# %%
area_columns = [col for col in df.columns if col.startswith('area ')]
area_dict = df[area_columns].iloc[0].to_dict()
print(area_dict)
# Out:
# {'area EP.1': 'Partial', 'area EP.2': 'Partial', 'area EP.3': 'Partial', 'area CP.1': 'Yes', 'area CP.2': 'Partial', 'area CP.3': 'No', 'area CP.4': 'Partial', 'area CP.5': 'Partial', 'area CP.6': 'Partial', 'area CF.1': 'Partial', 'area CF.2': 'Exempt', 'area CF.3': 'Yes', 'area CF.4': 'Not applicable'}
