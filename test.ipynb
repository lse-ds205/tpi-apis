# %%
import pandas as pd

# %%
file_path = './data/TPI ASCOR data - 13012025/ASCOR_assessments_results.xlsx'

# %%
df = pd.read_excel(file_path)
df
# Out:
#     Id Assessment date Publication date  Country Id               Country  \
# 0   82      31/10/2023       01/12/2023           8             Australia
# 1   88      31/10/2023       01/12/2023          25            Bangladesh
# 2   96      31/10/2023       01/12/2023          24              Barbados
# 3   91      31/10/2023       01/12/2023          18                Brazil
# 4   72      31/10/2023       01/12/2023          14                Canada
# ..  ..             ...              ...         ...                   ...
# 90  54      23/08/2024       01/11/2024          57               Türkiye
# 91  55      23/08/2024       01/11/2024          61  United Arab Emirates
# 92  22      23/08/2024       01/11/2024          22        United Kingdom
# 93   1      23/08/2024       01/11/2024           1         United States
# 94   6      23/08/2024       01/11/2024           6               Uruguay
#
#    area EP.1 indicator EP.1.a indicator EP.1.b indicator EP.1.c area EP.2  \
# ...

# %%
# Out:
# C:\Users\kbhatia2\AppData\Local\Temp\ipykernel_28604\126383051.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Assessment date'] = pd.to_datetime(df['Assessment date'])

# %%
df['Assessment date'] = pd.to_datetime(df['Assessment date'], format ='%d/%m/%y')
df['Publication date'] = pd.to_datetime(df['Publication date'], format ='%d/%m/%y')

# %%
selected_country = 'United Kingdom'
selected_year = 2023

# %%
mask = (
    (df['Country']==selected_country)&
    (df['Assessment date'].dt.year == selected_year)&
)
require_columns = [col for col in df.columns if col.startswith('area')]
df[mask][required_columns].iloc[0].to_dict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 mask = (
# ----> 2     (df['Country']==selected_country)&
#       3     (df['Assessment date'].dt.year == selected_year)&
#       4     df.columns.str.startswith('area')
#       5
#       6 )
#       8 df[mask].iloc[0].to_dict()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# ...
